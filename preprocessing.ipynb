# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("Copy of test_data.csv")
df.head()
# Out:
#    patient_id  Chloride  SGPT  Sodium  T4  WBC  female  male  parameter_value  \
# 0           0         0     0       0   0    1       0     1             8.10
# 1           1         0     0       0   1    0       0     1            13.00
# 2           2         0     0       0   1    0       0     1             7.10
# 3           3         0     0       0   0    1       0     1             5.62
# 4           4         0     0       0   0    1       0     1          9350.00
#
#    normalmark  normal  highproblem  lowproblem  reference_high  reference_low  \
# 0        True       1            0           0            10.0            4.0
# 1       False       0            1           0            12.0            4.5
# 2        True       1            0           0            12.0            4.5
# 3        True       1            0           0            10.0            4.0
# 4        True       1            0           0         10000.0         4000.0
#
#   age_group
# 0     adult
# ...

# %%
df.drop("normalmark", axis =1, inplace = True)

# %%
#df1=pd.get_dummies(df['gender'],drop_first=False)

# %%
#df = pd.concat([df1,df],axis =1)

# %%
#df.drop("gender", axis =1, inplace = True)

# %%
df.to_csv('Copy of test_data.csv')

# %%
df1=pd.get_dummies(df['standard_lab_parameter_name'],drop_first=False)

# %%
df = pd.concat([df1,df],axis =1)

# %%
df.head()
# Out:
#    Chloride  SGPT  Sodium  T4  WBC  patient_id standard_lab_parameter_name  \
# 0         0     0       0   0    1           0                         WBC
# 1         0     0       0   1    0           1                          T4
# 2         0     0       0   1    0           2                          T4
# 3         0     0       0   0    1           3                         WBC
# 4         0     0       0   0    1           4                         WBC
#
#    parameter_value     unit                        created_at  reference_high  \
# 0             8.10  10^3/μl  2020-01-05 09:06:51.396116+00:00            10.0
# 1            13.00    μg/dl  2020-11-03 09:16:15.785961+00:00            12.0
# 2             7.10    μg/dl  2020-10-31 02:25:49.721427+00:00            12.0
# 3             5.62  10^3/μl  2020-10-31 02:25:49.721427+00:00            10.0
# 4          9350.00     /cmm  2020-11-02 12:57:39.535672+00:00         10000.0
#
#    reference_low  female  male age_group
# ...

# %%
df.drop("created_at", axis =1, inplace = True)

# %%
df.head()
# Out:
#    Chloride  SGPT  Sodium  T4  WBC  patient_id  parameter_value  \
# 0         0     0       0   0    1           0             8.10
# 1         0     0       0   1    0           1            13.00
# 2         0     0       0   1    0           2             7.10
# 3         0     0       0   0    1           3             5.62
# 4         0     0       0   0    1           4          9350.00
#
#    reference_high  reference_low  female  male age_group
# 0            10.0            4.0       0     1     adult
# 1            12.0            4.5       0     1     adult
# 2            12.0            4.5       0     1     adult
# 3            10.0            4.0       0     1     adult
# 4         10000.0         4000.0       0     1       old

# %%
#df.to_csv('Copy of test_data.csv')

# %%
#df = df.drop("reference_high", axis =1)
df = df.drop("reference_low", axis =1)

# %%
df = df.drop("normalmark", axis =1)

# %%
df.head()
# Out:
#    patient_id  Chloride  SGPT  Sodium  T4  WBC  female  male  parameter_value  \
# 0           0         0     0       0   0    1       0     1           579.00
# 1           1         0     0       0   1    0       0     1             5.00
# 2           2         0     0       0   0    1       0     1             6.81
# 3           3         0     0       0   1    0       0     1             5.70
# 4           4         0     0       0   0    1       0     1             4.64
#
#    normal  highproblem  lowproblem age_group
# 0       0            1           0       old
# 1       1            0           0       old
# 2       1            0           0     adult
# 3       1            0           0     adult
# 4       1            0           0     adult

# %%
#df.to_csv('Copy of training_data.csv')

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,[12]]

# %%
x.head()
# Out:
#    patient_id  Chloride  SGPT  Sodium  T4  WBC  female  male  parameter_value  \
# 0           0         0     0       0   0    1       0     1           579.00
# 1           1         0     0       0   1    0       0     1             5.00
# 2           2         0     0       0   0    1       0     1             6.81
# 3           3         0     0       0   1    0       0     1             5.70
# 4           4         0     0       0   0    1       0     1             4.64
#
#    normal  highproblem  lowproblem
# 0       0            1           0
# 1       1            0           0
# 2       1            0           0
# 3       1            0           0
# 4       1            0           0

# %%
y.head()
# Out:
#   age_group
# 0       old
# 1       old
# 2     adult
# 3     adult
# 4     adult
